# %%
#Solutions by Himel Ghosh, Matricola: 2102750
#Problem 1: Introduction:
#Q1
if __name__ == '__main__':
    print("Hello, World!")
#Q2
import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
if n%2 != 0:
    print("Weird")
elif n%2 == 0 and 2 <= n <= 5:
    print("Not Weird")
elif n%2 == 0 and 6 <= n <= 20:
    print("Weird")
elif n%2 == 0 and n>20:
    print("Not Weird")
#Q3
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a+b)
    print(a-b)
    print(a*b)
#Q4
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)
#Q5
if __name__ == '__main__':
    n = int(input())
    for i in range(0,n):
        print(i*i)
#Q6
def is_leap(year):
    leap = False
    
    # Write your logic here
    if year%4 == 0 and year%100 != 0 or year%400 == 0:
        leap = True
    
    return leap

year = int(input())
print(is_leap(year))
#Q7
if __name__ == '__main__':
    n = int(input())
    
for i in range(1,n+1):
    print(i,end='')

# %%
#Solutions by Himel Ghosh, Matricola: 2102750
#Problem 2: Data Types:
#1 List comprehensions
if __name__ == '__main__':
    x = int(input())
    y = int(input())
    z = int(input())
    n = int(input())
    solution = [
        [i,j,k]
        for i in range(x+1)
        for j in range(y+1)
        for k in range(z+1)
        if i+j+k != n
    ]
    print(solution)

#2 Find the Runner Up score
if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    arr = list(set(arr)) #taking distinct values as a list
    arr.sort() #sorting the list in ascending order
    runnersUp=arr[-2] #picking the 2nd largest value
    print(runnersUp)

#3 Nested Lists
if __name__ == '__main__':
    students=[]
    for _ in range(int(input())):
        name = input()
        score = float(input())
        students.append([name,score]) #I created a nested list of the data
    students.sort(key=lambda x:x[1], reverse=False) 
    #sorted the list using lambda function by sorting the index=1 
    #element  in each list of the nested list in ascending order
    secondLowestGrade=None
    for i in range(1,len(students)):
        if students[i][1]>students[i-1][1]:
            secondLowestGrade=students[i][1]
            break
    #noted the second lowest grade using a for loop 
    #as there can be similar grades
    studentwithSLG=[]
    for name,score in students:
        if score==secondLowestGrade:
            studentwithSLG.append(name)
    studentwithSLG.sort() 
    #sorted the students name with second lowest grade alphabetically.
    for name in studentwithSLG:
        print(name)

#4 Finding the percentage
if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()
    average=round(sum(student_marks[query_name]) / len(student_marks[query_name]), 2)
    print("{0:.2f}".format(average))
    #I used google search to understand the syntax of the format to get floating point till 2 decimal places.

#5 Lists
if __name__ == '__main__':
    N = int(input())
    mlist=[]
    for _ in range(N):
        command= input().split()
        if command[0]=="insert":
            i=int(command[1])
            e=int(command[2])
            mlist.insert(i,e)
        elif command[0]=="print":
            print(mlist)
        elif command[0]=="remove":
            e=int(command[1])
            mlist.remove(e)
        elif command[0]=="append":
            e=int(command[1])
            mlist.append(e)
        elif command[0]=="sort":
            mlist.sort()
        elif command[0]=="pop":
            mlist.pop()
        elif command[0]=="reverse":
            mlist.reverse()
    

#6 Tuples
if __name__ == '__main__':
    n = int(input())
    integer_list = map(int, input().split())
    t=tuple(integer_list)
    print(hash(t))

# %%
#Solutions by Himel Ghosh, Matricola: 2102750
#Problem 2: Strings:
#1 Swap cases
def swap_case(s):
    return s.swapcase()

if __name__ == '__main__':
    s = input()
    result = swap_case(s)
    print(result)
#2 Split and join:


def split_and_join(line):
    # write your code here
    line=line.split(" ")
    line="-".join(line)
    return line

if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(result)
#3 What's your name?
def print_full_name(first, last):
    # Write your code here
    print("Hello "+first+" "+last+"! You just delved into python.")
if __name__ == '__main__':
    first_name = input()
    last_name = input()
    print_full_name(first_name, last_name)
#4 Mutations
def mutate_string(string, position, character):
    return string[:position]+character+string[position+1:]

if __name__ == '__main__':
    s = input()
    i, c = input().split()
    s_new = mutate_string(s, int(i), c)
    print(s_new)
#5 Find a string
def count_substring(string, sub_string):
    return sum(string[i:].startswith(sub_string) for i in range(len(string)))

if __name__ == '__main__':
    string = input().strip()
    sub_string = input().strip()
    
    count = count_substring(string, sub_string)
    print(count)
#6 String Validators
if __name__ == '__main__':
    s = input()
    print(any(c.isalnum() for c in s))
    print(any(c.isalpha() for c in s))
    print(any(c.isdigit() for c in s))
    print(any(c.islower() for c in s))
    print(any(c.isupper() for c in s))
    #to do this solution, I read about the any() function of print() in google.
#7 Text Alignment
#Replace all ______ with rjust, ljust or center. 

thickness = int(input()) #This must be an odd number
c = 'H'

#Top Cone
for i in range(thickness):
    print((c*i).rjust(thickness-1)+c+(c*i).ljust(thickness-1))

#Top Pillars
for i in range(thickness+1):
    print((c*thickness).center(thickness*2)+(c*thickness).center(thickness*6))

#Middle Belt
for i in range((thickness+1)//2):
    print((c*thickness*5).center(thickness*6))    

#Bottom Pillars
for i in range(thickness+1):
    print((c*thickness).center(thickness*2)+(c*thickness).center(thickness*6))    

#Bottom Cone
for i in range(thickness):
    print(((c*(thickness-i-1)).rjust(thickness)+c+(c*(thickness-i-1)).ljust(thickness)).rjust(thickness*6))
#8 Text Wrap
import textwrap

def wrap(string, max_width):
    return textwrap.fill(string,max_width)

if __name__ == '__main__':
    string, max_width = input(), int(input())
    result = wrap(string, max_width)
    print(result)
#9 Designer Door Mat
def design_Door_Mat(n, m):
    
    for i in range(1,n,2):
        pattern=".|."*i
        print(pattern.center(m,"-"))
    text="WELCOME"
    print(text.center(m,"-"))
    for i in range(n-2,0,-2):
        pattern=".|."*i
        print(pattern.center(m,"-"))
if __name__ == "__main__":
    n,m = map(int,input().split())
    if n%2==1 and m==3*n:
        design_Door_Mat(n,m)
#10 String Formatting
def print_formatted(number):
    # your code goes here
    for i in range(1,number+1):
        w=len(bin(number)[2:])
        print(str(i).rjust(w,' '),end=' ')
        print(oct(i)[2:].rjust(w,' '),end=' ')
        print(hex(i)[2:].upper().rjust(w,' '),end=' ')
        print(bin(i)[2:].rjust(w,' '))
    

if __name__ == '__main__':
    n = int(input())
    print_formatted(n)
    
#11 Alphabet Rangoli
#for solving this problem, I referred Google and some Hackerrank Discussions.
def print_rangoli(size):
    # your code goes here
    import string
    n=size
    alphabet = string.ascii_lowercase
    pattern = []
    for i in range(n):
        s = "-".join(alphabet[i:n])
        pattern.append((s[::-1]+s[1:]).center(4*n-3, "-"))
    #print(pattern)    
    print('\n'.join(pattern[:0:-1]+pattern))
    
if __name__ == '__main__':
    n = int(input())
    print_rangoli(n)

#12 Capitalize
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the solve function below.
def solve(s):
    s=' '.join(word.capitalize() for word in s.split(' '))
    return s

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    s = input()

    result = solve(s)

    fptr.write(result + '\n')

    fptr.close()

# %%
#Prob 3: Sets
#1 Intrduction to sets
def average(array):
    # your code goes here
    distinct=list(set(array))
    s=sum(distinct)
    l=len(distinct)
    return float(s/l)

if __name__ == '__main__':
    n = int(input())
    arr = list(map(int, input().split()))
    result = average(arr)
    print(result)

#2 No idea!
#I consulted the hackerrank discussions to understand the question's expectation of inputs,
#after understanding the different inputs, I used my logic on it.
def get_happiness(U, A, B):
    
    happiness = 0
    for i in U: 
        if i in A: 
            happiness = happiness +1 
        elif i in B: 
            happiness = happiness -1
    print(happiness)
if __name__ == '__main__':
    n,m = input().split()
    U = input().split()
    A = set(input().split())
    B = set(input().split())
    get_happiness(U,A,B)
#3 Set.add()
if __name__ == "__main__":
    n= int(input())
    A=set()
    for i in range(n):
        A.add(input())
    size= len(A)
    print(size)
#4 Set discard, remove, pop:

n = int(input())
s = set(map(int, input().split()))
N= int(input())
for i in range(N):
    command= input().split()
    if command[0] == "pop":
        s.pop()
    elif command[0] == "remove":
        e=int(command[1])
        if e in s:
            s.remove(e)
    elif command[0] == "discard":
        e=int(command[1])
        if e in s:
            s.discard(e)
print(sum(list(s)))

#5 Set Union operation
n=int(input())
A=set(input().split())
b=int(input())
B=set(input().split())
C=A|B
print(len(C))

#6 Set Intersection:
n=int(input())
A=set(input().split())
b=int(input())
B=set(input().split())
C=A&B
print(len(C))
#7 Set Difference
n=int(input())
A=set(input().split())
b=int(input())
B=set(input().split())
C=A-B
print(len(C))

#8 Set Symmetric Difference
n=int(input())
A=set(input().split())
b=int(input())
B=set(input().split())
C=A^B
print(len(C))

#9 Set Mutations:
size=int(input())
A=set([int(x) for x in input().split()])

N=int(input())
for i in range(N):
    command= input().split()
    B=set([int(x) for x in input().split()])
    if command[0] == "update":
        A.update(B)
    elif command[0] == "intersection_update":
        A.intersection_update(B)
    elif command[0] == "difference_update":
        A.difference_update(B)
    elif command[0] == "symmetric_difference_update":
        A.symmetric_difference_update(B)
s=sum(list(A))
print(s)
#10 Symmetric Difference:

m=int(input())
A=set([int(x) for x in input().split()])
n=int(input())
B=set([int(x) for x in input().split()])
C=A^B
C=list(C)
C.sort()
for i in range(len(C)):
    print(C[i])
#11 check subset:
t=int(input())
for i in range(t):
    n1=int(input())
    A=set([int(x) for x in input().split()])
    n2=int(input())
    B=set([int(x) for x in input().split()])
    print(A.issubset(B))
#12 Strict superset
A=set([int(x) for x in input().split()])
n=int(input())
res=[]
for i in range(n):
    B=set([int(x) for x in input().split()])
    res.append(A.issuperset(B))
if False in res:
    print("False")
else:
    print("True")
#The Captain's Room:

K=int(input())
A=input().split()
unique=set()
repeated=set()
for e in A:
    if e in unique:
        repeated.add(e)
    else:
        unique.add(e)
CaptainRoom=unique-repeated
print(''.join(CaptainRoom))

# %%
## Collections ##
#1 Counter:
from collections import Counter
X=int(input())
size=[int(i) for i in input().split()]
N=int(input())
stock=Counter(size)
money = 0
for i in range(N):
    shoe_size,price = map(int,input().split())
    if stock.get(shoe_size):
        money += price
        stock[shoe_size] -= 1
print(money)

#2 Defaultdict
from collections import defaultdict
n,m = map(int,input().split())
A=defaultdict(list)
for i in range(n):
    letter = input()
    A[letter].append(i)
for j in range(m):
    letter = input()
    if letter in A:
        for k in A[letter]:
            print(k+1,end=' ')
        print()
    else:
        print('-1')
#3 NamedTuple:
from collections import namedtuple
N=int(input())
StudentData=namedtuple('StudentData',input().split())
std=[]
totalMarks=0
for _ in range(N):
    std=StudentData(*input().split())
    totalMarks+=int(std.MARKS)
avg=totalMarks/N
print(avg)

#4 Ordered Dictionary:

from collections import OrderedDict
N=int(input())
Orderedbuydata=OrderedDict()
for _ in range(N):
    data=input().split()
    item_name=' '.join(data[:-1])
    ## I consulted the hackkerank discussion to unpack the inputs.
    net_price=int(data[-1])
    if item_name in Orderedbuydata:
        Orderedbuydata[item_name]+=int(net_price)
    else:
        Orderedbuydata[item_name]=int(net_price)
for item, price in Orderedbuydata.items():
    print(str(item)+' '+str(price))

#5 Word Order:
from collections import Counter
n=int(input())
distinct=set()
wordList=[]
for _ in range(n):
    word=input()
    wordList.append(word)
    distinct.add(word)
occurrences=Counter(wordList)
print(len(distinct))
for value in occurrences.values():
    print(value,end=" ")

#6 Deque
from collections import deque
n=int(input())
d=deque()
for _ in range(n):
    command = input().split()
    if command[0] == "append":
        e=int(command[1])
        d.append(e)
    elif command[0] == "pop":
        d.pop()
    elif command[0] == "popleft":
        d.popleft()
    elif command[0] == "appendleft":
        e=int(command[1])
        d.appendleft(e)
for e in d:
    print(e,end=" ")
    
#7 Piling Up!

## consulted hackkerrank discussions to solve this problem
from collections import deque
t=int(input())
for _ in range(t):
    size = int(input())
    cubes = deque(map(int,input().split()))
    top = float('inf')
    case = True
    
    while(len(cubes) > 1 and case):
        
        left, right = cubes[0], cubes[-1]
        if left <= top and right <= top:
            
            if left >= right:
                top = cubes.popleft()
            else: top = cubes.pop()
        
        else: case = False
    
    print("Yes") if case and cubes[0] <= top else print("No")
    
#8 Company Logo:

import math
import os
import random
import re
import sys
from collections import Counter


if __name__ == '__main__':
    s = input()
    c=Counter(s)
    o=sorted(c.elements())
    mc=Counter(''.join(o)).most_common(3)
    d=dict(mc)
    [print(k, v) for k, v in d.items()]

# %%
##Prob 4 Date and Time
#1 Calendar:
import calendar
m, d, y=map(int, input().split())
dayname=(calendar.day_name[calendar.weekday(y, m, d)]).upper()
print(dayname)

#2 Time Delta:

import math
import os
import random
import re
import sys
from datetime import datetime

# Complete the time_delta function below.
def time_delta(t1, t2):
    date_format = "%a %d %b %Y %H:%M:%S %z" 
    t1=datetime.strptime(t1, date_format)
    t2=datetime.strptime(t2, date_format)
    d=abs(t1-t2)
    return str(int(d.total_seconds()))

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input())

    for t_itr in range(t):
        t1 = input()

        t2 = input()

        delta = time_delta(t1, t2)

        fptr.write(delta + '\n')

    fptr.close()

# %%
##Prob 5 Errors & Exceptions
#1 Exceptions
T=int(input())
for _ in range(T):
    a, b= input().split()
    try:
        print(int(a)//int(b))
    except ZeroDivisionError as e:
        print("Error Code:", e)
    except ValueError as e:
        print("Error Code:", e)

# %%
##Prob 6: built-ins
#1 Zipped!
N, X=map(int, input().split())
z=[0.0]*N
for i in range(X):
    k=0
    for j in map(float, input().split()):
        z[k]=z[k]+ j
        k=k+1
for i in z:
    print(i/X)
#2 Athlete Sort:
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    nm = input().split()

    n = int(nm[0])

    m = int(nm[1])

    arr = []

    for _ in range(n):
        arr.append(list(map(int, input().rstrip().split())))

    k = int(input())
    arr.sort(key=lambda row: row[k])
    for row in arr:
        print(*row)
#3 ginortS
S = input()

lowercase = sorted([x for x in S if x.islower()])
uppercase = sorted([x for x in S if x.isupper()])
oddnumber = sorted([x for x in S if x.isdigit() and int(x) % 2 != 0])
evennumber = sorted([x for x in S if x.isdigit() and int(x) % 2 == 0])

result = lowercase + uppercase + oddnumber + evennumber
print(''.join(result))

# %%
##Prob 7 Python Functionals: map and lambda function:
cube = lambda x: x**3 # complete the lambda function 

def fibonacci(n):
    # return a list of fibonacci numbers
    if n>2:
        fibo= [0, 1]
        x, y = 0, 1
        for i in range(n-2):
            a= fibo[x]
            b= fibo[y]
            fibo.append(a+ b)
            x+=1
            y+=1
    else:
        fibo = [i for i in range(n)]
    return fibo

if __name__ == '__main__':
    n = int(input())
    print(list(map(cube, fibonacci(n))))

# %%
## Numpy ##
#1 Arrays:
import numpy

def arrays(arr):
    # complete this function
    # use numpy.array
    a= numpy.array(arr, float)
    return a[::-1]

arr = input().strip().split(' ')
result = arrays(arr)
print(result)

#2 Shape and Reshape
import numpy as np
arr = [int(x) for x in input().split(' ')]
a=np.array(arr)
b=a.reshape(3, 3)
print(b)

#3 Transpose and Flatten:
import numpy
n, m= map(int, input().split())
matrix=[]
for _ in range(n):
    a = [int(x) for x in input().split()]
    matrix.append(a)
mat=numpy.array(matrix)
print(mat.transpose())
print(mat.flatten())

#4 Concatenate:
import numpy
n, m, p = map(int, input().split())
arr1 = []
arr2 = []
for _ in range(n):
    a = [int(x) for x in input().split()]
    arr1.append(a)
for _ in range(m):
    b = [int(y) for y in input().split()]
    arr2.append(b)
c=numpy.array(arr1)
d=numpy.array(arr2)
print(numpy.concatenate((c,d),axis= 0))

#5 Zeros and Ones:

import numpy
dimensions=tuple([int(x) for x in input().split()])
array1 = numpy.zeros(dimensions, dtype=int)
array2 = numpy.ones(dimensions, dtype=int)
print(array1)
print(array2)

#6 Eye and Identity
import numpy
numpy.set_printoptions(legacy='1.13')
n, m = map(int, input().split())
a= numpy.eye(n, m, k=0)
print(a)

#7 Array Maths:
import numpy as np
n, m = map(int, input().split())
A= []
B= []
for _ in range(n):
    a=[int(x) for x in input().split()]
    A.append(a)
for _ in range(n):
    b=[int(y) for y in input().split()]
    B.append(b)
print(np.add(A,B))
print(np.subtract(A,B))
print(np.multiply(A,B))
print(np.floor_divide(A,B))
print(np.mod(A,B))
print(np.power(A,B))

#8 Floor, Ceil & Rint

import numpy as np
np.set_printoptions(legacy='1.13')
A =np.array([float(x) for x in input().split()])
print(np.floor(A))
print(np.ceil(A))
print(np.rint(A))

#9 Sum and Prod:
import numpy
n, m= map(int, input().split())
array=[]
for _ in range(n):
    a=[int(x) for x in input().split()]
    array.append(a)
arr=numpy.array(array)
s= numpy.sum(arr, axis=0)
pr= numpy.prod(s, axis=None)
print(pr)

#10 Min and Max:

import numpy
n, m= map(int, input().split())
array=[]
for _ in range(n):
    a=[int(x) for x in input().split()]
    array.append(a)
arr=numpy.array(array)
minima= numpy.min(arr, axis=1)
maxim= numpy.max(minima)
print(maxim)

#11 Mean, Var and Std:
import numpy
n, m= map(int, input().split())
array=[]
for _ in range(n):
    a=[int(x) for x in input().split()]
    array.append(a)
arr=numpy.array(array)
mean=numpy.mean(arr, axis=1)
var=numpy.var(arr, axis=0)
std=numpy.std(arr, axis=None)
print(mean)
print(var)
print(round(std, 11))

#12 Dot and Cross:
import numpy
N = int(input())
A=[]
B=[]
for _ in range(N):
    a=[int(x) for x in input().split()]
    A.append(a)
for _ in range(N):
    b=[int(x) for x in input().split()]
    B.append(b)
mult= numpy.dot(A, B)
print(mult)

#13 Inner and Outer

import numpy
A= [int(x) for x in input().split()]
B= [int(x) for x in input().split()]
A= numpy.array(A)
B= numpy.array(B)
print(numpy.inner(A,B))
print(numpy.outer(A,B))

#14 Polynomials

import numpy
coefficients= [float(x) for x in input().split()]
x = int(input())
print(numpy.polyval(coefficients, x))

#15 Linear Algebra
import numpy
N= int(input())
A=[]
for _ in range(N):
    a=[float(x) for x in input().split()]
    A.append(a)
print(round(numpy.linalg.det(A), 2))

# %%
## Closures and Decorators ##
##1 
def wrapper(f):
    def fun(l):
        f(["+91 " + c[-10:-5] + " " + c[-5:] for c in l])
    return fun

@wrapper
def sort_phone(l):
    print(*sorted(l), sep='\n')

if __name__ == '__main__':
    l = [input() for _ in range(int(input()))]
    sort_phone(l) 
##2 Name directory
import operator

def person_lister(f):
    def inner(people):
        # complete the function
        return map(f, sorted(people, key= lambda p: int(p[2])))
    return inner

@person_lister
def name_format(person):
    return ("Mr. " if person[3] == "M" else "Ms. ") + person[0] + " " + person[1]

if __name__ == '__main__':
    people = [input().split() for i in range(int(input()))]
    print(*name_format(people), sep='\n')

# %%
## XML ##
#1 Find the score:
import sys
import xml.etree.ElementTree as etree

def get_attr_number(node):
    # your code goes here
    return sum([len(element.items()) for element in tree.iter()])

if __name__ == '__main__':
    sys.stdin.readline()
    xml = sys.stdin.read()
    tree = etree.ElementTree(etree.fromstring(xml))
    root = tree.getroot()
    print(get_attr_number(root))

# %%
## RegEx ##
#1. Detect Floating Point Number
from re import search
for _ in range(int(input())):
    print(search(r"^([\+\-]){0,1}\d*\.\d+$", input()) is not None)
#2. Re.split()
regex_pattern = r"[,.]"	# Do not delete 'r'.

import re
print("\n".join(re.split(regex_pattern, input())))
#3
import re
pattern = re.compile(r'([a-zA-Z0-9])\1{1,}')
match=re.search(pattern,input())
print(match.group(1) if match else -1)
#4
import re

regex = re.findall(r'(?<=[qwrtypsdfghjklzxcvbnm])[AEIOUaeiou]{2,}(?=[qwrtypsdfghjklzxcvbnm])', input())

if regex:
    for re in regex:
        print(re)
else:
    print("-1")
#5
import re
S, k = input(), input()
match = re.finditer(fr'(?={k})', S)
if re.search(fr'{k}', S) is not None:
    for m in match:
        print((m.start(), m.start() + len(k) - 1))
else:
    print((-1, -1))
